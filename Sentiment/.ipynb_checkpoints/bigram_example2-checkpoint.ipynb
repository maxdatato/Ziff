# %%
import collections
import nltk.classify.util, nltk.metrics
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews
import pandas as pd
nltk.download('stopwords')
nltk.download('movie_reviews')

# Importing the dataset
df = pd.read_csv('sentiment.tsv', delimiter = '\t', header=None,names = ["sentiment", "text"])
 
def evaluate_classifier(featx):
    negids = movie_reviews.fileids('neg')
    posids = movie_reviews.fileids('pos')
 
    negfeats = [(featx(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
    posfeats = [(featx(movie_reviews.words(fileids=[f])), 'pos') for f in posids]
 
    negcutoff = len(negfeats)*3/4
    poscutoff = len(posfeats)*3/4
 
    trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]
    testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
    
#     testfeats =  df['text']
 
    classifier = NaiveBayesClassifier.train(trainfeats)
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)
 
    for i, (feats, label) in enumerate(testfeats):
            refsets[label].add(i)
            observed = classifier.classify(feats)
            testsets[observed].add(i)
 
    print 'accuracy:', nltk.classify.util.accuracy(classifier, testfeats)
#     print 'pos precision:', nltk.metrics.precision(refsets['pos'], testsets['pos'])
#     print 'pos recall:', nltk.metrics.recall(refsets['pos'], testsets['pos'])
#     print 'neg precision:', nltk.metrics.precision(refsets['neg'], testsets['neg'])
#     print 'neg recall:', nltk.metrics.recall(refsets['neg'], testsets['neg'])
    classifier.show_most_informative_features()
# Out:
# [nltk_data] Downloading package stopwords to /opt/pynb/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /opt/pynb/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
def word_feats(words):
    return dict([(word, True) for word in words])
 
# evaluate_classifier(word_feats)

# %%
from nltk.corpus import stopwords
stopset = set(stopwords.words('english'))
 
def stopword_filtered_word_feats(words):
    return dict([(word, True) for word in words if word not in stopset])
 
# evaluate_classifier(stopword_filtered_word_feats)

# %%
import itertools
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
 
def bigram_word_feats(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return dict([(ngram, True) for ngram in itertools.chain(words, bigrams)])
 
# evaluate_classifier(bigram_word_feats)

# %%
import itertools
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
 
def bigram_word_feats(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return dict([(ngram, True) for ngram in itertools.chain(words, bigrams)])

featx = bigram_word_feats
negids = movie_reviews.fileids('neg')
posids = movie_reviews.fileids('pos')
 
negfeats = [(featx(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
posfeats = [(featx(movie_reviews.words(fileids=[f])), 'pos') for f in posids]
 
negcutoff = len(negfeats)*3/4
poscutoff = len(posfeats)*3/4
 
trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]
testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
    
#     testfeats =  df['text']
 
classifier = NaiveBayesClassifier.train(trainfeats)
refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)
 
for i, (feats, label) in enumerate(testfeats):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
 
print 'accuracy:', nltk.classify.util.accuracy(classifier, testfeats)
#     print 'pos precision:', nltk.metrics.precision(refsets['pos'], testsets['pos'])
#     print 'pos recall:', nltk.metrics.recall(refsets['pos'], testsets['pos'])
#     print 'neg precision:', nltk.metrics.precision(refsets['neg'], testsets['neg'])
#     print 'neg recall:', nltk.metrics.recall(refsets['neg'], testsets['neg'])
classifier.show_most_informative_features()
# Out:
# accuracy: 0.816
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#      (u'matt', u'damon') = True              pos : neg    =     12.3 : 1.0
#         (u'give', u'us') = True              neg : pos    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#   (u'absolutely', u'no') = True              neg : pos    =     10.6 : 1.0

# %%
feats
# Out:
# {(u"'", u's'): True,
#  (u'-', u'chosen'): True,
#  (u'-', u'seeing'): True,
#  (u'/', u'director'): True,
#  (u';', u'neither'): True,
#  (u'address', u'them'): True,
#  (u'airplane', u'started'): True,
#  (u'almost', u'felt'): True,
#  (u'also', u'recalls'): True,
#  (u'although', u'these'): True,
#  (u'amazing', u'coincidence'): True,
#  (u'andrew', u'niccol'): True,
#  (u'announcer', u'warns'): True,
#  (u'answer', u'them'): True,
#  (u'asked', u'them'): True,
#  (u'at', u'every'): True,
#  (u'became', u'known'): True,
#  (u'becomes', u'determined'): True,
#  (u'been', u'fake'): True,
#  (u'best', u'not'): True,
#  (u'big', u'hoax'): True,
#  (u'both', u'films'): True,
#  (u'built', u'by'): True,
#  (u'by', u'andrew'): True,
#  (u'by', u'government'): True,
#  (u'cage', u'-'): True,
#  (u'cameo', u'as'): True,
#  (u'carefully', u'scripted'): True,
#  (u'certainly', u'didn'): True,
#  (u'chaos', u'theory'): True,
#  (u'coffee', u'breaks'): True,
#  (u'comes', u'back'): True,
#  (u'comes', u'under'): True,
#  (u'coming', u'apart'): True,
#  (u'communities', u'built'): True,
#  (u'concept', u'behind'): True,
#  (u'concepts', u'into'): True,
#  (u'day', u'during'): True,
#  (u'deal', u'more'): True,
#  (u'doors', u'open'): True,
#  (u'drama', u'theme'): True,
#  (u'dream', u'opus'): True,
#  (u'drive', u'carefully'): True,
#  (u'elaborate', u'hoax'): True,
#  (u'elaborate', u'trap'): True,
#  (u'elevator', u'accident'): True,
#  (u'elevator', u'doors'): True,
#  (u'end', u'showed'): True,
#  (u'epic', u'music'): True,
#  (u'even', u'worse'): True,
#  (u'every', u'turn'): True,
#  (u'everything', u'else'): True,
#  (u'exactly', u'describes'): True,
#  (u'falling', u';'): True,
#  (u'falls', u'apart'): True,
#  (u'family', u'drama'): True,
#  (u'few', u'interviews'): True,
#  (u'few', u'quick'): True,
#  (u'find', u'out'): True,
#  (u'first', u'sign'): True,
#  (u'found', u'myself'): True,
#  (u'functioning', u'properly'): True,
#  (u'get', u'something'): True,
#  (u'gets', u'even'): True,
#  (u'glass', u'has'): True,
#  (u'got', u'over'): True,
#  (u'government', u'scientists'): True,
#  (u'great', u'ideas'): True,
#  (u'green', u'led'): True,
#  (u'grim', u'war'): True,
#  (u'grip', u'sees'): True,
#  (u'guards', u'grab'): True,
#  (u'handled', u'competently'): True,
#  (u'hidden', u'camera'): True,
#  (u'hidden', u'cameras'): True,
#  (u'ideas', u';'): True,
#  (u'idyllic', u'life'): True,
#  (u'if', u'hollywood'): True,
#  (u'instant', u'classic'): True,
#  (u'interesting', u'stories'): True,
#  (u'interesting', u'worlds'): True,
#  (u'into', u'place'): True,
#  (u'introduces', u'some'): True,
#  (u'its', u'own'): True,
#  (u'itself', u'asked'): True,
#  (u'jim', u'carrey'): True,
#  (u'jurassic', u'park'): True,
#  (u'just', u'happens'): True,
#  (u'know', u'by'): True,
#  (u'known', u'worldwide'): True,
#  (u'last', u'hope'): True,
#  (u'led', u'numbers'): True,
#  (u'light', u'?'): True,
#  (u'light', u'falling'): True,
#  (u'little', u'town'): True,
#  (u'long', u'setup'): True,
#  (u'look', u'forward'): True,
#  (u'lower', u'part'): True,
#  (u'man', u'who'): True,
#  (u'missed', u'opportunities'): True,
#  (u'myself', u'wondering'): True,
#  (u'nearly', u'hits'): True,
#  (u'next', u'day'): True,
#  (u'no', u'sooner'): True,
#  (u'no', u'token'): True,
#  (u'no', u'unnecessarily'): True,
#  (u'not', u'fair'): True,
#  (u'numbers', u'obscuring'): True,
#  (u'obstructions', u'covering'): True,
#  (u'office', u'building'): True,
#  (u'open', u'up'): True,
#  (u'opportunities', u'here'): True,
#  (u'other', u'oddities'): True,
#  (u'our', u'protagonist'): True,
#  (u'overall', u'quality'): True,
#  (u'overflying', u'airplane'): True,
#  (u'own', u'little'): True,
#  (u'own', u'terms'): True,
#  (u'paneled', u'door'): True,
#  (u'particularly', u'disappointed'): True,
#  (u'perfect', u'name'): True,
#  (u'performance', u'at'): True,
#  (u'philip', u'glass'): True,
#  (u'pick', u'up'): True,
#  (u'picking', u'up'): True,
#  (u'picture', u'perfect'): True,
#  (u'planned', u'communities'): True,
#  (u'plenty', u'following'): True,
#  (u'plot', u'slows'): True,
#  (u'properly', u'until'): True,
#  (u'protagonist', u'lives'): True,
#  (u'psychological', u'impact'): True,
#  (u'questions', u'came'): True,
#  (u'quick', u'title'): True,
#  (u'quickly', u'moves'): True,
#  (u'radio', u'explains'): True,
#  (u'radio', u'jams'): True,
#  (u'reality', u'comes'): True,
#  (u'really', u'suspicious'): True,
#  (u'right', u'into'): True,
#  (u'same', u'timbre'): True,
#  (u'scientists', u'promised'): True,
#  (u'score', u'sounds'): True,
#  (u'security', u'guards'): True,
#  (u'seeing', u'creator'): True,
#  (u'seemed', u'exclusive'): True,
#  (u'setup', u'explaining'): True,
#  (u'she', u'says'): True,
#  (u'should', u'root'): True,
#  (u'slows', u'down'): True,
#  (u'small', u'cameo'): True,
#  (u'so', u'distracted'): True,
#  (u'some', u'missed'): True,
#  (u'square', u'looking'): True,
#  (u'started', u'coming'): True,
#  (u'starts', u'picking'): True,
#  (u'still', u'beautiful'): True,
#  (u'still', u'keeping'): True,
#  (u'stopped', u'by'): True,
#  (u'stories', u'set'): True,
#  (u'straight', u'shot'): True,
#  (u'studio', u'light'): True,
#  (u'such', u'as'): True,
#  (u'suspicion', u'aroused'): True,
#  (u'suspicious', u'now'): True,
#  (u'tangerine', u'dream'): True,
#  (u'television', u'program'): True,
#  (u'theme', u'music'): True,
#  (u'then', u'right'): True,
#  (u'then', u'why'): True,
#  (u'there', u'were'): True,
#  (u'these', u'names'): True,
#  (u'think', u'about'): True,
#  (u'this', u'type'): True,
#  (u'title', u'cards'): True,
#  (u'token', u'scene'): True,
#  (u'too', u'easily'): True,
#  (u'town', u'square'): True,
#  (u'true', u'-'): True,
#  (u'trying', u'vainly'): True,
#  (u'two', u'security'): True,
#  (u'two', u'seemed'): True,
#  (u'unassuming', u'man'): True,
#  (u'under', u'attack'): True,
#  (u'unnecessarily', u'long'): True,
#  (u'wanders', u'around'): True,
#  (u'warns', u'listeners'): True,
#  (u'we', u'pick'): True,
#  (u'well', u'made'): True,
#  (u'were', u'some'): True,
#  (u'westworld', u'told'): True,
#  (u'while', u'still'): True,
#  (u'why', u'would'): True,
#  (u'wondering', u'if'): True,
#  (u'would', u'compare'): True,
#  (u'writer', u'/'): True,
#  (u'written', u'by'): True,
#  (u'you', u'get'): True,
#  (u'you', u'know'): True,
#  (u'your', u'entire'): True,
#  u'"': True,
#  u"'": True,
#  u'(': True,
#  u')': True,
#  u',': True,
#  u'-': True,
#  u'.': True,
#  u'/': True,
#  u';': True,
#  u'?': True,
#  u'a': True,
#  u'about': True,
#  u'accident': True,
#  u'actions': True,
#  u'address': True,
#  u'airplane': True,
#  u'all': True,
#  u'almost': True,
#  u'also': True,
#  u'although': True,
#  u'amazing': True,
#  u'americans': True,
#  u'an': True,
#  u'and': True,
#  u'andrew': True,
#  u'announcer': True,
#  u'another': True,
#  u'answer': True,
#  u'apart': True,
#  u'apparently': True,
#  u'appears': True,
#  u'are': True,
#  u'around': True,
#  u'aroused': True,
#  u'artificial': True,
#  u'as': True,
#  u'asked': True,
#  u'at': True,
#  u'attack': True,
#  u'awakening': True,
#  u'back': True,
#  u'be': True,
#  u'beautiful': True,
#  u'became': True,
#  u'because': True,
#  u'becomes': True,
#  u'been': True,
#  u'before': True,
#  u'behind': True,
#  u'best': True,
#  u'better': True,
#  u'big': True,
#  u'both': True,
#  u'breaks': True,
#  u'brings': True,
#  u'brisk': True,
#  u'building': True,
#  u'built': True,
#  u'burbank': True,
#  u'but': True,
#  u'by': True,
#  u'cage': True,
#  u'california': True,
#  u'came': True,
#  u'cameo': True,
#  u'camera': True,
#  u'cameras': True,
#  u'capitalized': True,
#  u'captive': True,
#  u'car': True,
#  u'cards': True,
#  u'carefully': True,
#  u'carrey': True,
#  u'carrying': True,
#  u'center': True,
#  u'certainly': True,
#  u'change': True,
#  u'chaos': True,
#  u'character': True,
#  u'choice': True,
#  u'chosen': True,
#  u'christof': True,
#  u'classic': True,
#  u'clicked': True,
#  u'coffee': True,
#  u'coincidence': True,
#  u'combine': True,
#  u'comes': True,
#  u'coming': True,
#  u'communities': True,
#  u'compare': True,
#  u'competently': True,
#  u'concept': True,
#  u'concepts': True,
#  u'corners': True,
#  u'counting': True,
#  u'covering': True,
#  u'creator': True,
#  u'criticize': True,
#  u'day': True,
#  u'deal': True,
#  u'death': True,
#  u'describes': True,
#  u'determined': True,
#  u'didn': True,
#  u'dinosaurs': True,
#  u'director': True,
#  u'disappointed': True,
#  u'distracted': True,
#  u'does': True,
#  u'don': True,
#  u'door': True,
#  u'doors': True,
#  u'down': True,
#  u'drama': True,
#  u'dream': True,
#  u'drive': True,
#  u'driven': True,
#  u'during': True,
#  u'earlier': True,
#  u'easily': True,
#  u'edge': True,
#  u'elaborate': True,
#  u'elevator': True,
#  u'else': True,
#  u'end': True,
#  u'ends': True,
#  u'enters': True,
#  u'entire': True,
#  u'epic': True,
#  u'era': True,
#  u'escape': True,
#  u'ethics': True,
#  u'even': True,
#  u'every': True,
#  u'everything': True,
#  u'exactly': True,
#  u'exclusive': True,
#  u'expense': True,
#  u'explaining': True,
#  u'explains': True,
#  u'fair': True,
#  u'fake': True,
#  u'falling': True,
#  u'falls': True,
#  u'family': True,
#  u'father': True,
#  u'fear': True,
#  u'felt': True,
#  u'few': True,
#  u'film': True,
#  u'films': True,
#  u'find': True,
#  u'first': True,
#  u'following': True,
#  u'for': True,
#  u'forward': True,
#  u'found': True,
#  u'frantic': True,
#  u'from': True,
#  u'functioning': True,
#  u'gattaca': True,
#  u'get': True,
#  u'gets': True,
#  u'glass': True,
#  u'got': True,
#  u'government': True,
#  u'grab': True,
#  u'great': True,
#  u'green': True,
#  u'grim': True,
#  u'grip': True,
#  u'guards': True,
#  u'handled': True,
#  u'happens': True,
#  u'happy': True,
#  u'has': True,
#  u'he': True,
#  u'help': True,
#  u'here': True,
#  u'hidden': True,
#  u'him': True,
#  u'his': True,
#  u'hits': True,
#  u'hoax': True,
#  u'hollywood': True,
#  u'home': True,
#  u'hope': True,
#  u'i': True,
#  u'idea': True,
#  u'ideas': True,
#  u'idyllic': True,
#  u'if': True,
#  u'impact': True,
#  u'in': True,
#  u'instant': True,
#  u'interesting': True,
#  u'interviews': True,
#  u'into': True,
#  u'introduces': True,
#  u'is': True,
#  u'isn': True,
#  u'it': True,
#  u'its': True,
#  u'itself': True,
#  u'jams': True,
#  u'jim': True,
#  u'jurassic': True,
#  u'just': True,
#  u'keep': True,
#  u'keeping': True,
#  u'keyboardist': True,
#  u'know': True,
#  u'known': True,
#  u'last': True,
#  u'leads': True,
#  u'learning': True,
#  u'led': True,
#  u'life': True,
#  u'light': True,
#  u'like': True,
#  u'listeners': True,
#  u'little': True,
#  u'lives': True,
#  u'long': True,
#  u'look': True,
#  u'looking': True,
#  u'lounge': True,
#  u'lower': True,
#  u'made': True,
#  u'man': True,
#  u'may': True,
#  u'meanwhile': True,
#  u'memory': True,
#  u'mind': True,
#  u'missed': True,
#  u'more': True,
#  u'movements': True,
#  u'moves': True,
#  u'movie': True,
#  u'much': True,
#  u'music': True,
#  u'myself': True,
#  u'name': True,
#  u'names': True,
#  u'nbc': True,
#  u'nearly': True,
#  u'necessary': True,
#  u'neither': True,
#  u'nevertheless': True,
#  u'next': True,
#  u'niccol': True,
#  u'no': True,
#  u'normal': True,
#  u'not': True,
#  u'now': True,
#  u'numbers': True,
#  u'nurse': True,
#  u'obscuring': True,
#  u'obstructions': True,
#  u'ocean': True,
#  u'oddities': True,
#  u'of': True,
#  u'office': True,
#  u'on': True,
#  u'one': True,
#  u'open': True,
#  u'opens': True,
#  u'opportunities': True,
#  u'opus': True,
#  u'or': True,
#  u'other': True,
#  u'our': True,
#  u'out': True,
#  u'over': True,
#  u'overall': True,
#  u'overflying': True,
#  u'own': True,
#  u'pacing': True,
#  u'pain': True,
#  u'paneled': True,
#  u'park': True,
#  u'part': True,
#  u'particularly': True,
#  u'pedestrian': True,
#  u'people': True,
#  u'perfect': True,
#  u'performance': True,
#  u'perhaps': True,
#  u'permeates': True,
#  u'person': True,
#  u'philip': True,
#  u'pick': True,
#  u'picking': True,
#  u'picture': True,
#  u'place': True,
#  u'planned': True,
#  u'plenty': True,
#  u'plot': True,
#  u'point': True,
#  u'powaqqatsi': True,
#  u'president': True,
#  u'program': True,
#  u'promised': True,
#  u'properly': True,
#  u'protagonist': True,
#  u'psychological': True,
#  u'quality': True,
#  u'quell': True,
#  u'questions': True,
#  u'quick': True,
#  u'quickly': True,
#  u'radio': True,
#  u'real': True,
#  u'reality': True,
#  u'really': True,
#  u'recalls': True,
#  u'right': True,
#  u'robots': True,
#  u'root': True,
#  u's': True,
#  u'sail': True,
#  u'sake': True,
#  u'same': True,
#  u'saw': True,
#  u'says': True,
#  u'scene': True,
#  u'scenes': True,
#  u'scientists': True,
#  u'score': True,
#  u'scored': True,
#  u'screen': True,
#  u'scripted': True,
#  u'security': True,
#  u'see': True,
#  u'seeing': True,
#  u'seemed': True,
#  u'seems': True,
#  u'sees': True,
#  u'set': True,
#  u'setup': True,
#  u'she': True,
#  u'shot': True,
#  u'should': True,
#  u'show': True,
#  u'showed': True,
#  u'sight': True,
#  u'sign': True,
#  u'sky': True,
#  u'slows': True,
#  u'small': True,
#  u'smidgen': True,
#  u'snoots': True,
#  u'so': True,
#  u'some': True,
#  u'something': True,
#  u'sooner': True,
#  u'sort': True,
#  u'sound': True,
#  u'sounds': True,
#  u'spite': True,
#  u'square': True,
#  u'started': True,
#  u'starts': True,
#  u'stature': True,
#  u'still': True,
#  u'stopped': True,
#  u'stories': True,
#  u'story': True,
#  u'straight': True,
#  u'studio': True,
#  u'subject': True,
#  u'subjecting': True,
#  u'such': True,
#  u'suspicion': True,
#  u'suspicious': True,
#  u't': True,
#  u'take': True,
#  u'tangerine': True,
#  u'television': True,
#  u'terms': True,
#  u'that': True,
#  u'the': True,
#  u'them': True,
#  u'theme': True,
#  u'then': True,
#  u'theory': True,
#  u'there': True,
#  u'these': True,
#  u'think': True,
#  u'this': True,
#  u'throw': True,
#  u'timbre': True,
#  u'title': True,
#  u'to': True,
#  u'token': True,
#  u'told': True,
#  u'tonight': True,
#  u'too': True,
#  u'town': True,
#  u'trap': True,
#  u'trauma': True,
#  u'tries': True,
#  u'trouble': True,
#  u'true': True,
#  u'truman': True,
#  u'truth': True,
#  u'try': True,
#  u'trying': True,
#  u'turn': True,
#  u'tv': True,
#  u'two': True,
#  u'type': True,
#  u'unassuming': True,
#  u'unaware': True,
#  u'under': True,
#  u'unnecessarily': True,
#  u'until': True,
#  u'up': True,
#  u'vainly': True,
#  u'view': True,
#  u'voice': True,
#  u'wanders': True,
#  u'war': True,
#  u'warns': True,
#  u'was': True,
#  u'wasn': True,
#  u'way': True,
#  u'we': True,
#  u'weir': True,
#  u'well': True,
#  u'were': True,
#  u'westworld': True,
#  u'what': True,
#  u'whatever': True,
#  u'when': True,
#  u'where': True,
#  u'whether': True,
#  u'while': True,
#  u'who': True,
#  u'why': True,
#  u'wife': True,
#  u'with': True,
#  u'wondering': True,
#  u'work': True,
#  u'world': True,
#  u'worlds': True,
#  u'worldwide': True,
#  u'worse': True,
#  u'would': True,
#  u'writer': True,
#  u'written': True,
#  u'you': True,
#  u'your': True}
